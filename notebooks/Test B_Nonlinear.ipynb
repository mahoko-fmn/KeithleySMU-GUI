# %%
from src.keithley.simulator import Keithley2450Simulato
from src.keithley.load_model import NonlinearLoad

device = Keithley2450Simulator(load_model=NonlinearLoad(a=0.001, b=0.0001))
device.set_voltage_setpoint(5)
device.output_on()

device.measure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.keithley.load_model import NonlinearLoad
# ----> 3 device = Keithley2450Simulator(load_model=NonlinearLoad(a=0.001, b=0.0001))
#       4 device.set_voltage_setpoint(5)
#       5 device.output_on()
#
# NameError: name 'Keithley2450Simulator' is not defined
