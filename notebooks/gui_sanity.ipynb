# %%
import sys
sys.executable

# %%
from src.keithley.simulator import Keithley2450Simulator

device = Keithley2450Simulator(load_resistance=1000)
device.connect()
device.set_voltage_setpoint(0.5)
device.output_on()

device.measure()
# Out:
# {'voltage': 0.495364103090234,
#  'current': 0.0005002371169276714,
#  'resistance': 990.258592030583}
