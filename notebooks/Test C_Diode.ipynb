# %%
from src.keithley.simulator import Keithley2450Simulator
from src.keithley.load_model import DiodeLoad

device = Keithley2450Simulator(load_model = DiodeLoad())
device.set_voltage_setpoint(0.7)
device.output_on()

device.measure()
# Out:
# {'voltage': 0.7004429299456125,
#  'current': 5.362990800020232e-06,
#  'resistance': 130606.77447795922}
