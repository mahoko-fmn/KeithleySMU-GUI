# %%
#%load_exit autoreload        # these two lines should always be included inside the 
#%autoreload 2                # the first cell for every notebook

import sys
sys.executable
# Out:
# '/home/malebo/Desktop/MSC/thesis/venv/bin/python3.11'
